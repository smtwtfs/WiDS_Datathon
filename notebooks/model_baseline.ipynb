# %% [markdown]
# <a href="https://colab.research.google.com/github/smtwtfs/WiDS_Datathon/blob/2025/notebooks/model_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import xgboost as xgb
import numpy as np

# %%
df_res = pd.read_excel("/content/drive/MyDrive/WiDS_datathon_2025/TRAIN/TRAINING_SOLUTIONS.xlsx")
df_q = pd.read_excel("/content/drive/MyDrive/WiDS_datathon_2025/TRAIN/TRAIN_QUANTITATIVE_METADATA.xlsx")

# %%
df_all = df_res.merge(df_q, on = "participant_id")

# %%
df_all
# Out:
#      participant_id  ADHD_Outcome  Sex_F  EHQ_EHQ_Total  ColorVision_CV_Score  \
# 0      UmrK0vMLopoR             1      1          40.00                    13
# 1      CPaeQkhcjg7d             1      0         -94.47                    14
# 2      Nb4EetVPm3gs             1      0         -46.67                    14
# 3      p4vPhVu91o4b             1      1         -26.68                    10
# 4      M09PXs7arQ5E             1      1           0.00                    14
# ...             ...           ...    ...            ...                   ...
# 1208   Atx7oub96GXS             0      0          87.80                    14
# 1209   groSbUfkQngM             0      1          77.80                    14
# 1210   zmxGvIrOD0bt             0      1          16.68                    14
# 1211   rOmWFuJCud5G             0      0          53.40                    14
# 1212   k8HhHnnu2wmt             0      0         -57.80                    14
#
# ...

# %%
X = df_all.drop(columns= ['participant_id', 'ADHD_Outcome', 'Sex_F'])
y_s = df_all['Sex_F']
y_a = df_all['ADHD_Outcome']

# %%
dtrain_s = xgb.DMatrix(X, y_s)
dtrain_a = xgb.DMatrix(X, y_a)

# %%
model_s = xgb.train(params = {}, dtrain = dtrain_s)
model_a = xgb.train(params = {}, dtrain = dtrain_a)

# %%
# pred
# Out:
# UsageError: Line magic function `%md` not found.

# %%
test_df = pd.read_excel('/content/drive/MyDrive/WiDS_datathon_2025/TEST/TEST_QUANTITATIVE_METADATA.xlsx')
test_df.head()
# Out:
#   participant_id  EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  \
# 0   Cfwaf5FX7jWK          60.03                  14.0             5.0
# 1   vhGrzmvA3Hjq          86.71                  12.0             3.0
# 2   ULliyEXjy4OV          26.68                  13.0             3.0
# 3   LZfeAb1xMtql          93.38                  13.0             3.0
# 4   EnFOUv0YK1RG         -93.38                  14.0             3.0
#
#    APQ_P_APQ_P_ID  APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  \
# 0            16.0             41.0             19.0            11.0
# 1            13.0             43.0             18.0            15.0
# 2            14.0             36.0             16.0            14.0
# 3            19.0             41.0             17.0            18.0
# 4            13.0             42.0             19.0            16.0
#
#    APQ_P_APQ_P_PP  SDQ_SDQ_Conduct_Problems  SDQ_SDQ_Difficulties_Total  \
# ...

# %%
dtest = xgb.DMatrix(test_df.drop(columns = ['participant_id']))

# %%
(df_all['ADHD_Outcome'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-b205ff4d0128> in <cell line: 0>()
# ----> 1 mean(df_all['ADHD_Outcome'])
#
# NameError: name 'mean' is not defined

# %%
pred_s = model_s.predict(dtest)
pred_a = model_a.predict(dtest)

# %%
sample_sub = pd.read_excel('/content/drive/MyDrive/WiDS_datathon_2025/SAMPLE_SUBMISSION.xlsx')

# %%
sample_sub.head()
# Out:
#   participant_id  ADHD_Outcome  Sex_F
# 0   Cfwaf5FX7jWK             1      0
# 1   vhGrzmvA3Hjq             0      0
# 2   ULliyEXjy4OV             0      1
# 3   LZfeAb1xMtql             1      0
# 4   EnFOUv0YK1RG             1      0

# %%
sample_sub.dtypes
# Out:
# participant_id    object
# ADHD_Outcome       int64
# Sex_F              int64
# dtype: object

# %%
our_res = pd.DataFrame({'participant_id': test_df.participant_id, 'ADHD_Outcome': (pred_a > 0.5).astype(int), 'Sex_F': (pred_s > 0.5).astype(int)})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-2ff9eb852d12> in <cell line: 0>()
# ----> 1 our_res = pd.DataFrame({'participant_id': test_df.participant_id, 'ADHD_Outcome': (pred_a > 0.5).astype(int64), 'Sex_F': (pred_s > 0.5).astype(int64)})
#
# NameError: name 'int64' is not defined

# %%
our_res.head()
# Out:
#   participant_id  ADHD_Outcome  Sex_F
# 0   Cfwaf5FX7jWK             1      0
# 1   vhGrzmvA3Hjq             1      1
# 2   ULliyEXjy4OV             0      0
# 3   LZfeAb1xMtql             1      0
# 4   EnFOUv0YK1RG             1      0

# %%
our_res.to_excel('/content/drive/MyDrive/WiDS_datathon_2025/results/res_20250222.xlsx')

# %%
our_res.to_csv('/content/drive/MyDrive/WiDS_datathon_2025/results/res_2025022201.csv')

# %%
sample_sub.to_csv('/content/drive/MyDrive/WiDS_datathon_2025/results/res_sample_sub.csv', header=True)
